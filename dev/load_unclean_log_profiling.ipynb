# %%
import pandas as pd
import io
import gzip
import re

# %%
path='unclean_log.log.gz'

# %%
df=pd.read_csv(path,
                 sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])', 
                 engine='python', na_values=['-'], header=None,
                 usecols=[0, 3, 4, 5, 6, 7, 8,10],
                 names=['ip', 'time', 'request', 'status', 'size', 'referer',
                 'user_agent','req_time'])

# %%
wrong_lines={}
def convert_int_feedback_index(row,col,lines):
    #function to be used with .apply
    try:
        ans = int(row[col])
    except:
        wrong_lines[row['index']] = str(lines[row['index']])[1:-3]
        ans= pd.np.nan
    return ans

def convert_log_with_feedback(df,col):
    file = gzip.open(path)
    lines = file.readlines()
    wrong_lines.clear()
    df_index = df.reset_index()
    df_index[col] = df_index.apply(convert_int_feedback_index,axis=1,col=col,lines=lines)
    if len(wrong_lines.keys()) != 0:
        print("Warning! Some lines couldn't be converted properly")
    df_index.pop('index')
    file.close()
    return df_index

# %%
df = convert_log_with_feedback(df,'status')
# Out:
# Warning! Some lines couldn't be converted properly

# %% [markdown]
# First, let's drop the lines that were wrong

# %%
df = df.drop(wrong_lines.keys())

# %% [markdown]
# The plan is to add the unusual lines to our dataframe manually.
# Let's have a look at those unusual lines

# %%
str(wrong_lines[249242])
# Out:
# '\'111.22.117.229, 111.22.117.229 - - [19/Sep/2018:22:17:40 +0200] "GET /agent/10577/bdl HTTP/1.1" 204 - "-" "okhttp/3.8.0" apibackend.site.fr 429282'

# %% [markdown]
# They're close enough to regular lines. Hence, we should be able to get a good split with the "sep" regex we used before. Let's have a look :

# %%
g=wrong_lines[249242]
re.split(r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',g)
# Out:
# ["'111.22.117.229,",
#  '111.22.117.229',
#  '-',
#  '-',
#  '[19/Sep/2018:22:17:40 +0200]',
#  '"GET /agent/10577/bdl HTTP/1.1"',
#  '204',
#  '-',
#  '"-"',
#  '"okhttp/3.8.0"',
#  'apibackend.site.fr',
#  '429282']

# %%
#Remember, there are 2 kinds of unusual lines. luckily, our split works for both :
g=wrong_lines[249386]
re.split(r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',g)
# Out:
# ["'111.22.116.184",
#  '"111.22.105.253, 111.22.105.253"',
#  '-',
#  '-',
#  '[19/Sep/2018:22:20:22 +0200]',
#  '"GET /agent/5983/bdl HTTP/1.1"',
#  '204',
#  '-',
#  '"-"',
#  '"okhttp/3.8.0"',
#  'apibackend.site.fr',
#  '512517']

# %% [markdown]
# That looks promising! Now let's explain our dataframe the group/column correspondance :

# %%
def unusual_line_to_dic(line):
    groups=re.split(r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',line)
    dic = {}
    dic['ip'] = groups[0]+groups[1]
    dic['time'] = groups[4]
    dic['request'] = groups[5]
    dic['status'] = groups[6]
    dic['referer'] = groups[8]
    dic['user_agent'] = groups[9]
    dic['req_time'] = groups[11]
    return dic

# %%
unusual_line_to_dic(wrong_lines[249242])
# Out:
# {'ip': "'111.22.117.229,111.22.117.229",
#  'time': '[19/Sep/2018:22:17:40 +0200]',
#  'request': '"GET /agent/10577/bdl HTTP/1.1"',
#  'status': '204',
#  'referer': '"-"',
#  'user_agent': '"okhttp/3.8.0"',
#  'req_time': '429282'}

# 275320    '111.22.115.161"111.22.97.27"  [19/Sep/2018:22:21:28 +0200]
# 275321    '111.22.115.161"111.22.96.57"  [19/Sep/2018:22:21:28 +0200]
# 275322   '111.22.115.161"111.22.27.203"  [19/Sep/2018:22:21:29 +0200]
# 275323   '111.22.115.161"111.22.38.148"  [19/Sep/2018:22:21:30 +0200]
# 275324   '111.22.116.184"111.22.59.122"  [19/Sep/2018:22:21:31 +0200]
# 275325    '111.22.116.184"111.22.96.79"  [19/Sep/2018:22:21:31 +0200]
# 275326   '111.22.115.161"111.22.38.148"  [19/Sep/2018:22:21:31 +0200]
# 275327    '111.22.116.184"111.22.33.62"  [19/Sep/2018:22:21:33 +0200]
# 275328  '111.22.115.161"111.22.104.169"  [19/Sep/2018:22:21:36 +0200]
# 275329  '111.22.116.184"111.22.104.169"  [19/Sep/2018:22:21:37 +0200]
# 275330   '111.22.115.161"111.22.37.206"  [19/Sep/2018:22:21:38 +0200]
# 275331   '111.22.116.184"111.22.34.195"  [19/Sep/2018:22:21:38 +0200]
# 275332   '111.22.116.184"111.22.37.146"  [19/Sep/2018:22:21:39 +0200]
# 275333   '111.22.116.184"111.22.37.206"  [19/Sep/2018:22:21:40 +0200]
# 275334   '111.22.115.161"111.22.41.160"  [19/Sep/2018:22:21:42 +0200]
# 275335    '111.22.116.184"111.22.27.47"  [19/Sep/2018:22:21:42 +0200]
# 275336    '111.22.115.161"111.22.97.27"  [19/Sep/2018:22:21:43 +0200]
# 275337    '111.22.116.184"111.22.96.57"  [19/Sep/2018:22:21:43 +0200]
# 275338  '111.22.115.161"111.22.117.113"  [19/Sep/2018:22:21:43 +0200]
# 275339   '111.22.116.184"111.22.41.254"  [19/Sep/2018:22:21:45 +0200]
# 275340   '111.22.116.184"111.22.41.160"  [19/Sep/2018:22:21:57 +0200]
#
#                                                   request status    size  \
# 0                          "GET /agent/4231/bdl HTTP/1.1"    204     NaN
# 1                          "GET /agent/4230/bdl HTTP/1.1"    204     NaN
# 2                          "GET /agent/4652/bdl HTTP/1.1"    204     NaN
# 3                          "GET /agent/5402/bdl HTTP/1.1"    204     NaN
# 4                          "GET /agent/7978/bdl HTTP/1.1"    204     NaN
# 5                          "GET /agent/6508/bdl HTTP/1.1"    204     NaN
# 6                          "GET /agent/6531/bdl HTTP/1.1"    204     NaN
# 7                         "GET /agent/10546/bdl HTTP/1.1"    204     NaN
# 8                          "GET /agent/7030/bdl HTTP/1.1"    204     NaN
# 9       "GET /bdl/1007762/updated_at?datetime=2018-09-...    401    42.0
# 10                         "GET /agent/6851/bdl HTTP/1.1"    204     NaN
# 11                         "GET /agent/5916/bdl HTTP/1.1"    204     NaN
# 12                         "GET /agent/4354/bdl HTTP/1.1"    204     NaN
# 13                         "GET /agent/5378/bdl HTTP/1.1"    204     NaN
# 14      "GET /bdl/1007762/updated_at?datetime=2018-09-...    200  9960.0
# 15                         "GET /agent/7115/bdl HTTP/1.1"    204     NaN
# 16      "GET /bdl/1012043/updated_at?datetime=2018-09-...    304     NaN
# 17                        "GET /agent/10768/bdl HTTP/1.1"    204     NaN
# 18                         "GET /agent/6244/bdl HTTP/1.1"    204     NaN
# 19                         "GET /agent/7898/bdl HTTP/1.1"    204     NaN
# 20                         "GET /agent/7650/bdl HTTP/1.1"    204     NaN
# 21                        "GET /agent/11238/bdl HTTP/1.1"    204     NaN
# 22                         "GET /agent/5498/bdl HTTP/1.1"    204     NaN
# 23                         "GET /agent/7818/bdl HTTP/1.1"    204     NaN
# 24                         "GET /agent/4170/bdl HTTP/1.1"    204     NaN
# 25                         "GET /agent/7133/bdl HTTP/1.1"    204     NaN
# 26                        "GET /agent/10696/bdl HTTP/1.1"    204     NaN
# 27                         "GET /agent/4946/bdl HTTP/1.1"    204     NaN
# 28                         "GET /agent/6232/bdl HTTP/1.1"    204     NaN
# 29                         "GET /agent/5654/bdl HTTP/1.1"    204     NaN
# ...                                                   ...    ...     ...
# 275311                    "GET /agent/11344/bdl HTTP/1.1"    204     NaN
# 275312                     "GET /agent/5997/bdl HTTP/1.1"    204     NaN
# 275313                    "PUT /bdl/931542/sign HTTP/1.1"    500     NaN
# 275314                     "GET /agent/6900/bdl HTTP/1.1"    204     NaN
# 275315                     "GET /agent/6855/bdl HTTP/1.1"    204     NaN
# 275316                     "GET /agent/5289/bdl HTTP/1.1"    204     NaN
# 275317                     "GET /agent/6274/bdl HTTP/1.1"    204     NaN
# 275318                     "GET /agent/6988/bdl HTTP/1.1"    204     NaN
# 275319                     "GET /agent/4231/bdl HTTP/1.1"    204     NaN
# 275320                    "GET /agent/11344/bdl HTTP/1.1"    204     NaN
# 275321                     "GET /agent/5997/bdl HTTP/1.1"    204     NaN
# 275322                     "GET /agent/6855/bdl HTTP/1.1"    204     NaN
# 275323                     "GET /agent/6864/bdl HTTP/1.1"    204     NaN
# 275324  "GET /bdl/1014982/updated_at?datetime=2018-09-...    304     NaN
# 275325  "GET /bdl/1015615/updated_at?datetime=2018-09-...    304     NaN
# 275326                     "GET /agent/6864/bdl HTTP/1.1"    204     NaN
# 275327                     "GET /agent/4652/bdl HTTP/1.1"    204     NaN
# 275328                     "GET /agent/5506/bdl HTTP/1.1"    204     NaN
# 275329                     "GET /agent/5506/bdl HTTP/1.1"    204     NaN
# 275330                     "GET /agent/6549/bdl HTTP/1.1"    204     NaN
# 275331                     "GET /agent/7381/bdl HTTP/1.1"    204     NaN
# 275332                     "GET /agent/6129/bdl HTTP/1.1"    204     NaN
# 275333                     "GET /agent/6549/bdl HTTP/1.1"    204     NaN
# 275334                     "GET /agent/6988/bdl HTTP/1.1"    204     NaN
# 275335                     "GET /agent/4231/bdl HTTP/1.1"    204     NaN
# 275336                    "GET /agent/11344/bdl HTTP/1.1"    204     NaN
# 275337                     "GET /agent/5997/bdl HTTP/1.1"    204     NaN
# 275338                     "GET /agent/6144/bdl HTTP/1.1"    204     NaN
# 275339                     "GET /agent/7466/bdl HTTP/1.1"    204     NaN
# 275340                     "GET /agent/6988/bdl HTTP/1.1"    204     NaN
#
#        referer      user_agent req_time
# 0          "-"  "okhttp/3.8.0"  1296274
# 1          "-"  "okhttp/3.8.0"  1354244
# 2          "-"  "okhttp/3.8.0"  1478761
# 3          "-"  "okhttp/3.8.0"  1620763
# 4          "-"  "okhttp/3.8.0"   318981
# 5          "-"  "okhttp/3.8.0"  1804195
# 6          "-"  "okhttp/3.8.0"   875978
# 7          "-"  "okhttp/3.8.0"   287595
# 8          "-"  "okhttp/3.8.0"   366385
# 9          "-"  "okhttp/3.8.0"    25763
# 10         "-"  "okhttp/3.8.0"   719038
# 11         "-"  "okhttp/3.8.0"   747399
# 12         "-"  "okhttp/3.8.0"   497670
# 13         "-"  "okhttp/3.8.0"   463259
# 14         "-"  "okhttp/3.8.0"   285426
# 15         "-"  "okhttp/3.8.0"   399359
# 16         "-"  "okhttp/3.8.0"    90080
# 17         "-"  "okhttp/3.8.0"   143996
# 18         "-"  "okhttp/3.8.0"   387923
# 19         "-"  "okhttp/3.8.0"   239534
# 20         "-"  "okhttp/3.8.0"   247852
# 21         "-"  "okhttp/3.8.0"    77943
# 22         "-"  "okhttp/3.8.0"   398872
# 23         "-"  "okhttp/3.8.0"   271938
# 24         "-"  "okhttp/3.8.0"   456137
# 25         "-"  "okhttp/3.8.0"   471160
# 26         "-"  "okhttp/3.8.0"   113916
# 27         "-"  "okhttp/3.8.0"   465102
# 28         "-"  "okhttp/3.8.0"   437195
# 29         "-"  "okhttp/3.8.0"   413872
# ...        ...             ...      ...
# 275311     "-"  "okhttp/3.8.0"    53579
# 275312     "-"  "okhttp/3.8.0"   435997
# 275313     "-"  "okhttp/3.8.0"   342700
# 275314     "-"  "okhttp/3.8.0"   462997
# 275315     "-"  "okhttp/3.8.0"   542379
# 275316     "-"  "okhttp/3.8.0"   519152
# 275317     "-"  "okhttp/3.8.0"   492650
# 275318     "-"  "okhttp/3.8.0"   414732
# 275319     "-"  "okhttp/3.8.0"   344038
# 275320     "-"  "okhttp/3.8.0"    68884
# 275321     "-"  "okhttp/3.8.0"   461705
# 275322     "-"  "okhttp/3.8.0"   397749
# 275323     "-"  "okhttp/3.8.0"   468513
# 275324     "-"  "okhttp/3.8.0"    62406
# 275325     "-"  "okhttp/3.8.0"    65813
# 275326     "-"  "okhttp/3.8.0"   487266
# 275327     "-"  "okhttp/3.8.0"   573423
# 275328     "-"  "okhttp/3.8.0"   443559
# 275329     "-"  "okhttp/3.8.0"   540767
# 275330     "-"  "okhttp/3.8.0"   436585
# 275331     "-"  "okhttp/3.8.0"  1101227
# 275332     "-"  "okhttp/3.8.0"   471538
# 275333     "-"  "okhttp/3.8.0"   389601
# 275334     "-"  "okhttp/3.8.0"   548015
# 275335     "-"  "okhttp/3.8.0"   339476
# 275336     "-"  "okhttp/3.8.0"    57460
# 275337     "-"  "okhttp/3.8.0"   394278
# 275338     "-"  "okhttp/3.8.0"   447849
# 275339     "-"  "okhttp/3.8.0"   346553
# 275340     "-"  "okhttp/3.8.0"   384735
#
# [275341 rows x 8 columns]
